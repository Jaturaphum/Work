# %%
st =['ฟิลิปปินส์        6.8        7.0        7.1','เวียดนาม        5.48       5.78       6.4','อินโดนีเซีย      4.91       5.19       5.02','มาเลเซีย        4.2        4.0        4.3','ไทย           3.2         3.5        3.2','สิงคโปร์        2.0         2.0        1.1']

def mn():
    x = '          GDP Annual growth Rate 2016            '
    return x
print(mn())
print ('    ประเทศ  ',' ไตรมาสที่ 1',' ไตรมาสที่ 2',' ไตรมาสที่ 3')
print('**********************************************')
i = 1
for t in range(len(st)):
    print('%d' %(i), st[t])
    i += 1
else:
    pass

print('**********************************************')
print()
def ed():
    y = 'การหาค่าเฉลี่ย 3 ไตรมาสของทั้ง 6 ประเทศ'
    return y
print(ed())

print('ฟิลิปปินส์')
print('ไตรมาสที่ 1')
def cal():
    d = (6.8/20.9)*100
    return d
print(cal())

print('ไตรมาสที่ 2')
def cal():
    d = (7.0/20.9)*100
    return d
print(cal())

print('ไตรมาสที่ 3')
def cal():
    d = (7.1/20.9)*100
    return d
print(cal())

print('เวียดนาม')
print('ไตรมาสที่ 1')
def cal():
    d = (5.48/17.66)*100
    return d
print(cal())

print('ไตรมาสที่ 2')
def cal():
    d = (5.78/17.66)*100
    return d
print(cal())

print('ไตรมาสที่ 3')
def cal():
    d = (6.4/17.66)*100
    return d
print(cal())

print('อินโดเซีย')
print('ไตรมาสที่ 1')
def cal():
    d = (4.91/15.12)*100
    return d
print(cal())

print('ไตรมาสที่ 2')
def cal():
    d = (5.19/15.12)*100
    return d
print(cal())

print('ไตรมาสที่ 3')
def cal():
    d = (5.02/15.12)*100
    return d
print(cal())

print('มาเลเซีย')
print('ไตรมาสที่ 1')
def cal():
    d = (4.2/12.5)*100
    return d
print(cal())

print('ไตรมาสที่ 2')
def cal():
    d = (4.0/12.5)*100
    return d
print(cal())

print('ไตรมาสที่ 3')
def cal():
    d = (4.3/12.5)*100
    return d
print(cal())

print('ไทย')
print('ไตรมาสที่ 1')
def cal():
    d = (3.2/9.7)*100
    return d
print(cal())

print('ไตรมาสที่ 2')
def cal():
    d = (3.5/9.7)*100
    return d
print(cal())

print('ไตรมาสที่ 3')
def cal():
    d = (3.2/9.7)*100
    return d
print(cal())

print('สิงคโปร์')
print('ไตรมาสที่ 1')
def cal():
    d = (2.0/5.1)*100
    return d
print(cal())

print('ไตรมาสที่ 2')
def cal():
    d = (2.0/5.1)*100
    return d
print(cal())

print('ไตรมาสที่ 3')
def cal():
    d = (1.1/5.1)*100
    return d
print(cal())

def p1():
    t1 = 'นายจตุรภูมิ เสือประโคน รหัสนิสิต 6440200373 สาขาวิศวกรรมคอมพิวเตอร์'
    return t1
print (
    f'{p1()} คณะวิทยาศาสตร์เเละวิศวกรรมศาสตร์',
        sep='\n')
# Out:
#           GDP Annual growth Rate 2016
#     ประเทศ    ไตรมาสที่ 1  ไตรมาสที่ 2  ไตรมาสที่ 3
# **********************************************
# 1 ฟิลิปปินส์        6.8        7.0        7.1
# 2 เวียดนาม        5.48       5.78       6.4
# 3 อินโดนีเซีย      4.91       5.19       5.02
# 4 มาเลเซีย        4.2        4.0        4.3
# 5 ไทย           3.2         3.5        3.2
# 6 สิงคโปร์        2.0         2.0        1.1
# **********************************************
#
# การหาค่าเฉลี่ย 3 ไตรมาสของทั้ง 6 ประเทศ
# ฟิลิปปินส์
# ไตรมาสที่ 1
# 32.535885167464116
# ไตรมาสที่ 2
# 33.49282296650718
# ไตรมาสที่ 3
# 33.97129186602871
# เวียดนาม
# ไตรมาสที่ 1
# 31.03057757644394
# ไตรมาสที่ 2
# 32.72933182332956
# ไตรมาสที่ 3
# 36.2400906002265
# อินโดเซีย
# ไตรมาสที่ 1
# 32.473544973544975
# ไตรมาสที่ 2
# 34.32539682539683
# ไตรมาสที่ 3
# 33.201058201058196
# มาเลเซีย
# ไตรมาสที่ 1
# 33.6
# ไตรมาสที่ 2
# 32.0
# ไตรมาสที่ 3
# 34.4
# ไทย
# ไตรมาสที่ 1
# 32.98969072164949
# ไตรมาสที่ 2
# ...
